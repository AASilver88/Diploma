# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
# Perform object detection on an image
results = model("C:/Users/Samurai-kun/Diploma/img/Watermelons.jpg")
# Out:
# image 1/1 C:\Users\Samurai-kun\Diploma\img\Watermelons.jpg: 448x640 1 frisbee, 2 oranges, 1276.3ms
# Speed: 12.0ms preprocess, 1276.3ms inference, 13.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
from IPython.display import Image
Image("C:/Users/Samurai-kun/Diploma/img/Watermelons.jpg", width=320, height=240)

# %%
for result in results:
    result.show()

# %%
Image("C:/Users/Samurai-kun/Diploma/img/WatermelonBeefore.png", width=320, height=240)
